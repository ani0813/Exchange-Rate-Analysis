# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
main_df=pd.read_csv("CBAData.csv",parse_dates=["Date"], index_col=["Date"])
main_df = main_df.dropna()
main_df.head()
# Out:
#                USD
# Date
# 2002-01-31  564.39
# 2002-02-28  568.18
# 2002-03-31  576.96
# 2002-04-30  579.34
# 2002-05-31  582.22

# %%
plt.figure(figsize=(10,4))
plt.plot(main_df.USD)
plt.title("AMD/USD exchange rate for the years 2012-2022" ,fontsize=20)
plt.ylabel("Exchange Rate",fontsize=20)
for year in range(2002,2025):
    plt.axvline(pd.to_datetime(str(year)+"-01-01"),color="k",linestyle="--",alpha=0.8)

# %%
rolLmean = main_df.USD.rolling(12).mean()
rolLstd = main_df.USD.rolling(12).std()

plt.figure(figsize=(16,7))
mean = plt.plot(rolLmean, color='red', label='Rolling Mean')
std = plt.plot(rolLstd, color='black', label = 'Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show()

# %%
# ADF

from statsmodels.tsa.stattools import adfuller

X1 = main_df.USD
result = adfuller(X1)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -2.572424
# p-value: 0.098832
# Critical Values:
# 	1%: -3.460
# 	5%: -2.874
# 	10%: -2.574

# %%
# KPSS

from statsmodels.tsa.stattools import kpss
result = kpss(X1)
print('KPSS Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[3].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# KPSS Statistic: 0.314970
# p-value: 0.100000
# Critical Values:
# 	10%: 0.347
# 	5%: 0.463
# 	2.5%: 0.574
# 	1%: 0.739

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
acf_plot1 = plot_acf(X1,lags=15)
pacf_plot1 = plot_pacf(X1,lags=15)

# %%
train1 = main_df[:int(X1.shape[0]*0.9)]
test1 = main_df[int(X1.shape[0]*0.9):]

# %%
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics  import mean_squared_error

# %%
import itertools
p1=range(0,4)
q1=range(0,4)
d1=range(1,3)
pdq_combos1 =list(itertools.product(p1,d1,q1))
rmse1=[]  
order1=[]

# %%
for pdq in pdq_combos1:
    try:
        modelnew1=ARIMA(train1,order=pdq).fit()
        pred1=modelnew1.predict(start=len(train1),end=(len(main_df.USD)-1))
        error1=np.sqrt(mean_squared_error(test1,pred1))
        order1.append(pdq)
        rmse1.append(error1)
    except:
        continue

# %%
results1=pd.DataFrame(index=order1,data=rmse1,columns=["RMSE"])
results1.sort_values(by=["RMSE"], inplace=True)
results1
# Out:
#                  RMSE
# (2, 2, 2)  496.676391
# (0, 2, 0)  496.691938
# (1, 2, 0)  496.699829
# (2, 2, 0)  496.710810
# (3, 2, 0)  496.721607
# (0, 2, 3)  496.728370
# (1, 2, 1)  496.729274
# (1, 2, 3)  496.730387
# (1, 2, 2)  496.730834
# (2, 2, 1)  496.732026
# (0, 2, 2)  496.734669
# (3, 2, 2)  496.741337
# (3, 2, 1)  496.746807
# (0, 2, 1)  496.754435
# (3, 2, 3)  496.756816
# (2, 2, 3)  496.773136
# (3, 1, 3)  496.903589
# (1, 1, 1)  496.915523
# (3, 1, 2)  496.922064
# (2, 1, 1)  496.923057
# (1, 1, 2)  496.924292
# (2, 1, 2)  496.924723
# (3, 1, 1)  496.927758
# (3, 1, 0)  497.036567
# (2, 1, 0)  497.041089
# (0, 1, 3)  497.048013
# (0, 1, 2)  497.048342
# (1, 1, 0)  497.052817
# (0, 1, 1)  497.061537
# (0, 1, 0)  497.076404

# %%
model1=ARIMA(train1,order=(2,2,2))
fitted1=model1.fit()
print(fitted1.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                 D2.USD   No. Observations:                  214
# Model:                 ARIMA(2, 2, 2)   Log Likelihood                -757.289
# Method:                       css-mle   S.D. of innovations              8.246
# Date:                Tue, 12 Apr 2022   AIC                           1526.577
# Time:                        10:19:42   BIC                           1546.773
# Sample:                             2   HQIC                          1534.738
#
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0178      0.016      1.095      0.273      -0.014       0.050
# ar.L1.D2.USD     1.0066      0.170      5.927      0.000       0.674       1.339
# ar.L2.D2.USD    -0.0800      0.083     -0.960      0.337      -0.243       0.083
# ma.L1.D2.USD    -1.8680      0.152    -12.283      0.000      -2.166      -1.570
# ma.L2.D2.USD     0.8680      0.152      5.716      0.000       0.570       1.166
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0875           +0.0000j            1.0875            0.0000
# AR.2           11.4886           +0.0000j           11.4886            0.0000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# MA.2            1.1521           +0.0000j            1.1521            0.0000
# -----------------------------------------------------------------------------

# %%
fc1,se1,const1=fitted1.forecast(len(test1),alpha=0.05)
fc_series1 = pd.Series(fc1, index=test1.index)
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train1, label='training')
plt.plot(test1, label='actual')
plt.plot(fc_series1, label='forecast')
plt.legend(loc='upper left', fontsize=20)
plt.show()

# %%
import pmdarima as pm
model1_1=pm.auto_arima(train1,test1='adf',seasonal=False, start_P=0,trace=True,error_action='ignore', suppress_warnings=True,stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0] intercept   : AIC=1528.339, Time=1.12 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=1634.525, Time=0.02 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=1590.881, Time=0.11 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=1524.815, Time=0.07 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=1632.526, Time=0.04 sec
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=1524.556, Time=0.27 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=1526.548, Time=0.31 sec
#  ARIMA(1,2,2)(0,0,0)[0] intercept   : AIC=1526.551, Time=0.30 sec
#  ARIMA(0,2,2)(0,0,0)[0] intercept   : AIC=1524.577, Time=0.17 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=1574.435, Time=0.13 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=1522.621, Time=0.12 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=1522.815, Time=0.10 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=1588.882, Time=0.09 sec
#  ARIMA(2,2,1)(0,0,0)[0]             : AIC=1524.600, Time=0.28 sec
#  ARIMA(1,2,2)(0,0,0)[0]             : AIC=1524.609, Time=0.24 sec
#  ARIMA(0,2,2)(0,0,0)[0]             : AIC=1522.623, Time=0.11 sec
#  ARIMA(2,2,0)(0,0,0)[0]             : AIC=1572.437, Time=0.06 sec
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=1526.420, Time=0.44 sec
#
# Best model:  ARIMA(1,2,1)(0,0,0)[0]
# Total fit time: 4.100 seconds

# %%
model1_2=ARIMA(main_df,order=(1,2,1))
fitted1_2=model1_2.fit()
print(fitted1_2.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                 D2.USD   No. Observations:                  238
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                -854.151
# Method:                       css-mle   S.D. of innovations              8.713
# Date:                Tue, 12 Apr 2022   AIC                           1716.302
# Time:                        10:21:47   BIC                           1730.191
# Sample:                             2   HQIC                          1721.900
#
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0057      0.029      0.195      0.845      -0.052       0.063
# ar.L1.D2.USD     0.0682      0.073      0.929      0.353      -0.076       0.212
# ma.L1.D2.USD    -0.9609      0.037    -26.261      0.000      -1.033      -0.889
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           14.6694           +0.0000j           14.6694            0.0000
# MA.1            1.0407           +0.0000j            1.0407            0.0000
# -----------------------------------------------------------------------------
